# %%
import pickle

# %%
#function to load and define the data generally
def load_data(file):
    with open(file, 'rb') as f:
        data = pickle.load(f)
    training_data = data['X_train_rawdata']
    training_labels = data['Y_train']
    return training_data, training_labels

# %%
#declaring training data and training labels for all temperatures
training_dataT045, training_labelsT045 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T0.45_train_data.pkl')
training_dataT10, training_labelsT10 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.0_train_data.pkl')
training_dataT12, training_labelsT12 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.2_train_data.pkl')
training_dataT14, training_labelsT14 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.4_train_data.pkl')
training_dataT18, training_labelsT18 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.8_train_data.pkl')
training_dataT20, training_labelsT20 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T2.0_train_data.pkl')
#declaring test data and test labels for all temperatures 
test_dataT045, test_labelsT045 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T0.45_train_data.pkl')
test_dataT10, test_labelsT10 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.0_train_data.pkl')
test_dataT12, test_labelsT12 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.2_train_data.pkl')
test_dataT14, test_labelsT14 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.4_train_data.pkl')
test_dataT18, test_labelsT18 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T1.8_train_data.pkl')
test_dataT20, test_labelsT20 = load_data('/Users/claudia/Documents/git/sussman-schmidt/glass-neural-network/src/T2.0_train_data.pkl')

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(10,10,10,10,10,10,10,10,10,10), max_iter=1000, tol=0, n_iter_no_change=1000)

# %% [markdown]
# 1) Training the neural network using the T0.45 data set

# %%
# training the network with the T0.45 data
clf.fit(training_dataT045, training_labelsT045)
# Out:
# /Users/claudia/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1e-05,
#               hidden_layer_sizes=(10, 10, 10, 10, 10, 10, 10, 10, 10, 10),
#               max_iter=1000, n_iter_no_change=1000, tol=0)

# %%
import matplotlib.pyplot as plt
plt.plot(clf.loss_curve_)

# %%
from sklearn.metrics import accuracy_score

# %%
#using the T0.45 trained neural network to predict the labels for the other data sets 
test_predictT045 = clf.predict(test_dataT045) 

test_predictT10 = clf.predict(test_dataT10) 

test_predictT12 = clf.predict(test_dataT12) 

test_predictT14 = clf.predict(test_dataT14) 

test_predictT18 = clf.predict(test_dataT18)

test_predictT20 = clf.predict(test_dataT20)

# %%
#calculating the accuracy scores 
scoreT045 = accuracy_score(test_predictT045, test_labelsT045)
scoreT10 = accuracy_score(test_predictT10, test_labelsT10)
scoreT12 = accuracy_score(test_predictT12, test_labelsT12)
scoreT14 = accuracy_score(test_predictT14, test_labelsT14)
scoreT18 = accuracy_score(test_predictT18, test_labelsT18)
scoreT20 = accuracy_score(test_predictT20, test_labelsT20)

# %%
print(scoreT045)
print(scoreT10)
print(scoreT12)
print(scoreT14)
print(scoreT18)
print(scoreT20)
# Out:
# 0.7788157894736842
# 0.5690384615384615
# 0.5447115384615384
# 0.5304807692307693
# 0.5259615384615385
# 0.5242307692307693

# %%
temperatures = [0.45,1,1.2,1.4,1.8,2.0]
accuraciesT045 = [scoreT045, scoreT10, scoreT12, scoreT14, scoreT18, scoreT20]

# %%
plt.plot(temperatures, accuraciesT045, label = 'Neural Network Trained at T=0.45')
plt.ylim(.5,1)
plt.xlabel='Temperatures'
plt.ylabel = 'Classification Accuracy'
plt.title('Neural Network Trained at T=0.45')
plt.show()

# %% [markdown]
# 2) Training the neural network using the T1.0 data set

# %%
# training the network with the T1.0 data
clf.fit(training_dataT10, training_labelsT10)
# Out:
# /Users/claudia/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1e-05,
#               hidden_layer_sizes=(10, 10, 10, 10, 10, 10, 10, 10, 10, 10),
#               max_iter=1000, n_iter_no_change=1000, tol=0)

# %%
#using the T1.0 trained neural network to predict the labels for the other data sets 
test_predictT045 = clf.predict(test_dataT045) 

test_predictT10 = clf.predict(test_dataT10) 

test_predictT12 = clf.predict(test_dataT12) 

test_predictT14 = clf.predict(test_dataT14) 

test_predictT18 = clf.predict(test_dataT18)

test_predictT20 = clf.predict(test_dataT20)

# %%
#calculating the accuracy scores (T1.0 trained neural network) 
scoreT045 = accuracy_score(test_predictT045, test_labelsT045)
scoreT10 = accuracy_score(test_predictT10, test_labelsT10)
scoreT12 = accuracy_score(test_predictT12, test_labelsT12)
scoreT14 = accuracy_score(test_predictT14, test_labelsT14)
scoreT18 = accuracy_score(test_predictT18, test_labelsT18)
scoreT20 = accuracy_score(test_predictT20, test_labelsT20)

# %%
print(scoreT045)
print(scoreT10)
print(scoreT12)
print(scoreT14)
print(scoreT18)
print(scoreT20)
# Out:
# 0.6576315789473685
# 0.6107692307692307
# 0.5733653846153847
# 0.5508653846153846
# 0.5425961538461539
# 0.53875

# %%
accuraciesT10 = [scoreT045, scoreT10, scoreT12, scoreT14, scoreT18, scoreT20]

# %%
plt.plot(temperatures, accuraciesT10, label = 'Neural Network Trained at T=1.0')
plt.ylim(.5,.7)
plt.xlablel='Temperatures'
plt.ylabel = 'Classification Accuracy'
plt.title('Neural Network Trained at T=1.0')
plt.show()

# %% [markdown]
# 3) Training the neural network using the T1.2 data set

# %%
clf.fit(training_dataT12, training_labelsT12)
# Out:
# /Users/claudia/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1e-05,
#               hidden_layer_sizes=(10, 10, 10, 10, 10, 10, 10, 10, 10, 10),
#               max_iter=1000, n_iter_no_change=1000, tol=0)

# %%
#using the T1.2 trained neural network to predict the labels for the other data sets 
test_predictT045 = clf.predict(test_dataT045) 

test_predictT10 = clf.predict(test_dataT10) 

test_predictT12 = clf.predict(test_dataT12) 

test_predictT14 = clf.predict(test_dataT14) 

test_predictT18 = clf.predict(test_dataT18)

test_predictT20 = clf.predict(test_dataT20)

# %%
#calculating the accuracy scores (T1.2 trained neural network) 
scoreT045 = accuracy_score(test_predictT045, test_labelsT045)
scoreT10 = accuracy_score(test_predictT10, test_labelsT10)
scoreT12 = accuracy_score(test_predictT12, test_labelsT12)
scoreT14 = accuracy_score(test_predictT14, test_labelsT14)
scoreT18 = accuracy_score(test_predictT18, test_labelsT18)
scoreT20 = accuracy_score(test_predictT20, test_labelsT20)

# %%
print(scoreT045)
print(scoreT10)
print(scoreT12)
print(scoreT14)
print(scoreT18)
print(scoreT20)
# Out:
# 0.6460526315789473
# 0.5854807692307692
# 0.5750961538461539
# 0.5551923076923077
# 0.5446153846153846
# 0.5428846153846154

# %%
accuraciesT12 = [scoreT045, scoreT10, scoreT12, scoreT14, scoreT18, scoreT20]

# %%
plt.plot(temperatures, accuraciesT12, label = 'Neural Network Trained at T=1.2')
plt.ylim(.5,.7)
plt.xlablel='Temperatures'
plt.ylabel = 'Classification Accuracy'
plt.title('Neural Network Trained at T=1.2')
plt.show()

# %% [markdown]
# 4) Training the neural network using the T1.4 data set

# %%
# training the network with the T1.4 data
clf.fit(training_dataT14, training_labelsT14)
# Out:
# /Users/claudia/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1e-05,
#               hidden_layer_sizes=(10, 10, 10, 10, 10, 10, 10, 10, 10, 10),
#               max_iter=1000, n_iter_no_change=1000, tol=0)

# %%
#using the T1.4 trained neural network to predict the labels for the other data sets 
test_predictT045 = clf.predict(test_dataT045) 

test_predictT10 = clf.predict(test_dataT10) 

test_predictT12 = clf.predict(test_dataT12) 

test_predictT14 = clf.predict(test_dataT14) 

test_predictT18 = clf.predict(test_dataT18)

test_predictT20 = clf.predict(test_dataT20)

# %%
#calculating the accuracy scores (T1.4 trained neural network) 
scoreT045 = accuracy_score(test_predictT045, test_labelsT045)
scoreT10 = accuracy_score(test_predictT10, test_labelsT10)
scoreT12 = accuracy_score(test_predictT12, test_labelsT12)
scoreT14 = accuracy_score(test_predictT14, test_labelsT14)
scoreT18 = accuracy_score(test_predictT18, test_labelsT18)
scoreT20 = accuracy_score(test_predictT20, test_labelsT20)

# %%
print(scoreT045)
print(scoreT10)
print(scoreT12)
print(scoreT14)
print(scoreT18)
print(scoreT20)
# Out:
# 0.6364473684210527
# 0.5821153846153846
# 0.568173076923077
# 0.5695192307692307
# 0.5433653846153846
# 0.5335576923076923

# %%
accuraciesT14 = [scoreT045, scoreT10, scoreT12, scoreT14, scoreT18, scoreT20]

# %%
plt.plot(temperatures, accuraciesT14, label = 'Neural Network Trained at T=1.4')
plt.ylim(.5,.7)
plt.xlablel='Temperatures'
plt.ylabel = 'Classification Accuracy'
plt.title('Neural Network Trained at T=1.4')
plt.show()

# %% [markdown]
# 5) Training the neural network using the T1.8 data set

# %%
# training the network with the T1.8 data
clf.fit(training_dataT18, training_labelsT18)
# Out:
# /Users/claudia/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1e-05,
#               hidden_layer_sizes=(10, 10, 10, 10, 10, 10, 10, 10, 10, 10),
#               max_iter=1000, n_iter_no_change=1000, tol=0)

# %%
#using the T1.8 trained neural network to predict the labels for the other data sets 
test_predictT045 = clf.predict(test_dataT045) 

test_predictT10 = clf.predict(test_dataT10) 

test_predictT12 = clf.predict(test_dataT12) 

test_predictT14 = clf.predict(test_dataT14)

test_predictT18 = clf.predict(test_dataT18)

test_predictT20 = clf.predict(test_dataT20)

# %%
#calculating the accuracy scores (T1.8 trained neural network) 
scoreT045 = accuracy_score(test_predictT045, test_labelsT045)
scoreT10 = accuracy_score(test_predictT10, test_labelsT10)
scoreT12 = accuracy_score(test_predictT12, test_labelsT12)
scoreT14 = accuracy_score(test_predictT14, test_labelsT14)
scoreT18 = accuracy_score(test_predictT18, test_labelsT18)
scoreT20 = accuracy_score(test_predictT20, test_labelsT20)

# %%
print(scoreT045)
print(scoreT10)
print(scoreT12)
print(scoreT14)
print(scoreT20)
# Out:
# 0.6105263157894737
# 0.5748076923076924
# 0.5627884615384615
# 0.5554807692307693
# 0.5427884615384615

# %%
accuraciesT18 = [scoreT045, scoreT10, scoreT12, scoreT14, scoreT18, scoreT20]

# %%
plt.plot(temperatures, accuraciesT18, label = 'Neural Network Trained at T=1.8')
plt.ylim(.5,.7)
plt.xlablel='Temperatures'
plt.ylabel = 'Classification Accuracy'
plt.title('Neural Network Trained at T=1.8')
plt.show()

# %% [markdown]
# 6) Training the neural network using the T2.0 data set

# %%
# training the network with the T2.0 data
clf.fit(training_dataT20, training_labelsT20)
# Out:
# /Users/claudia/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1e-05,
#               hidden_layer_sizes=(10, 10, 10, 10, 10, 10, 10, 10, 10, 10),
#               max_iter=1000, n_iter_no_change=1000, tol=0)

# %%
plt.plot(clf.loss_curve_)

# %%
#using the T2.0 trained neural network to predict the labels for the other data sets 
test_predictT045 = clf.predict(test_dataT045) 

test_predictT10 = clf.predict(test_dataT10) 

test_predictT12 = clf.predict(test_dataT12) 

test_predictT14 = clf.predict(test_dataT14)

test_predictT18 = clf.predict(test_dataT18) 

test_predictT20 = clf.predict(test_dataT20)

# %%
#calculating the accuracy scores (T1.8 trained neural network) 
scoreT045 = accuracy_score(test_predictT045, test_labelsT045)
scoreT10 = accuracy_score(test_predictT10, test_labelsT10)
scoreT12 = accuracy_score(test_predictT12, test_labelsT12)
scoreT14 = accuracy_score(test_predictT14, test_labelsT14)
scoreT18 = accuracy_score(test_predictT18, test_labelsT18)
scoreT20 = accuracy_score(test_predictT20, test_labelsT20)

# %%
print(scoreT045)
print(scoreT10)
print(scoreT12)
print(scoreT14)
print(scoreT18)
print(scoreT20)
# Out:
# 0.560921052631579
# 0.56875
# 0.5557692307692308
# 0.5464423076923077
# 0.5463461538461538
# 0.5504807692307693

# %%
accuraciesT20 = [scoreT045, scoreT10, scoreT12, scoreT14, scoreT18, scoreT20]

# %%
plt.plot(temperatures, accuraciesT20, label = 'Neural Network Trained at T=2.0')
plt.ylim(.5,.7)

plt.title('Neural Network Trained at T=2.0')
plt.show()

# %% [markdown]
# Comparing all the trained networks and their ability to classification accuracies for other data sets

# %%
plt.plot(temperatures, accuraciesT045, color = "yellow", label = 'NN Trained at T0.45')
plt.plot(temperatures, accuraciesT10, color = "red", label = 'NN Trained at T1.0')
plt.plot(temperatures, accuraciesT12, color = "green", label = 'NN Trained at T1.2')
plt.plot(temperatures, accuraciesT14, color = "blue", label = 'NN Trained at T1.4')
plt.plot(temperatures, accuraciesT18, color = "orange", label = 'NN Trained at T1.8')
plt.plot(temperatures, accuraciesT20, color = "purple", label = 'NN Trained at T2.0')



#setting the range
plt.ylim(.5,1)

plt.legend()
plt.show()

# %%
plt.plot(temperatures, accuraciesT045, color = "yellow", label = 'NN Trained at T0.45')
plt.plot(temperatures, accuraciesT10, color = "red", label = 'NN Trained at T1.0')
plt.plot(temperatures, accuraciesT12, color = "green", label = 'NN Trained at T1.2')
plt.plot(temperatures, accuraciesT14, color = "blue", label = 'NN Trained at T1.4')
plt.plot(temperatures, accuraciesT18, color = "orange", label = 'NN Trained at T1.8')
plt.plot(temperatures, accuraciesT20, color = "purple", label = 'NN Trained at T2.0')



#setting the range
plt.ylim(.5,1)

plt.legend()
plt.show()

# %%
plt.plot(temperatures, accuraciesT045, color = "yellow", label = 'NN Trained at T0.45')
plt.plot(temperatures, accuraciesT10, color = "red", label = 'NN Trained at T1.0')
plt.plot(temperatures, accuraciesT12, color = "green", label = 'NN Trained at T1.2')
plt.plot(temperatures, accuraciesT14, color = "blue", label = 'NN Trained at T1.4')
plt.plot(temperatures, accuraciesT18, color = "orange", label = 'NN Trained at T1.8')
plt.plot(temperatures, accuraciesT20, color = "purple", label = 'NN Trained at T2.0')



#setting the range
plt.ylim(.5,1)

plt.legend()
plt.show()
